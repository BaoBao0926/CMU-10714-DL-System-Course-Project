# %% [markdown]
# ## This notebook is design specifically for new modules designed in the project

# %% [markdown]
# ### Maxpool2d

# %% [markdown]
# test Maxpool2d op

# %%
# !python3 -m pytest -l -v tests/hw4/test_conv.py::test_op_maxpool2d
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-9.0.1, pluggy-1.6.0 -- /root/10714-project/.venv/bin/python3
# cachedir: .pytest_cache
# rootdir: /root/10714-project
# configfile: pyproject.toml
# plugins: jaxtyping-0.3.3
# collecting ... Using HIP backend
# [Needle] Using HIP-optimized operators
# collected 34 items
#
# tests/hw4/test_conv.py::test_op_maxpool2d[needle.backend_ndarray.ndarray_backend_cpu-X_shape0-2-2-0] ]9;4;2;0\FAILED
# tests/hw4/test_conv.py::test_op_maxpool2d[needle.backend_ndarray.ndarray_backend_cpu-X_shape1-3-2-1] ]9;4;2;2\FAILED
# tests/hw4/test_conv.py::test_op_maxpool2d[needle.backend_ndarray.ndarray_backend_cpu-X_shape2-4-2-2] ]9;4;2;5\FAILED
# tests/hw4/test_conv.py::test_op_maxpool2d[needle.backend_ndarray.ndarray_backend_cpu-X_shape3-2-2-0] ]9;4;2;8\FAILED
# ...

# %% [markdown]
# test nn.MaxPool2d in needle

# %%
# !python3 -m pytest -l -v tests/hw4/test_conv.py::test_nn_maxpool2d_forward
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-9.0.1, pluggy-1.6.0 -- /root/10714-project/.venv/bin/python3
# cachedir: .pytest_cache
# rootdir: /root/10714-project
# configfile: pyproject.toml
# plugins: jaxtyping-0.3.3
# collecting ... Using needle backend
# collected 34 items
#
# tests/hw4/test_conv.py::test_nn_maxpool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape0-2-2-0] ]9;4;1;0\PASSED
# tests/hw4/test_conv.py::test_nn_maxpool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape1-3-2-1] ]9;4;1;2\PASSED
# tests/hw4/test_conv.py::test_nn_maxpool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape2-4-2-2] ]9;4;1;5\PASSED
# tests/hw4/test_conv.py::test_nn_maxpool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape3-2-2-0] ]9;4;1;8\PASSED
# ...

# %%
# !python3 -m pytest -l -v -k "nn_maxpool2d_forward"
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-9.0.1, pluggy-1.6.0 -- /home/rthu/10714/project/.venv/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/rthu/10714/project
# configfile: pyproject.toml
# plugins: jaxtyping-0.3.3
# collecting ... Using needle backend
# collected 2047 items / 2013 deselected / 34 selected
#
# tests/hw4/test_conv.py::test_nn_maxpool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape0-2-2-0] ]9;4;1;0\PASSED
# tests/hw4/test_conv.py::test_nn_maxpool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape1-3-2-1] ]9;4;1;2\PASSED
# tests/hw4/test_conv.py::test_nn_maxpool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape2-4-2-2] ]9;4;1;5\PASSED
# tests/hw4/test_conv.py::test_nn_maxpool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape3-2-2-0] ]9;4;1;8\PASSED
# ...

# %% [markdown]
# ### AdaptiveAvgPool2d

# %% [markdown]
# test AdaptiveAvgPool2d op

# %%
# !python3 -m pytest -l -v -k "op_adaptiveavgpool2d"
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-9.0.1, pluggy-1.6.0 -- /home/rthu/10714/project/.venv/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/rthu/10714/project
# configfile: pyproject.toml
# plugins: jaxtyping-0.3.3
# collecting ... Using needle backend
# collected 1981 items / 1949 deselected / 32 selected
#
# tests/hw4/test_conv.py::test_op_adaptiveavgpool2d[needle.backend_ndarray.ndarray_backend_cpu-X_shape0-output_size0] ]9;4;1;0\PASSED
# tests/hw4/test_conv.py::test_op_adaptiveavgpool2d[needle.backend_ndarray.ndarray_backend_cpu-X_shape1-output_size1] ]9;4;1;3\PASSED
# tests/hw4/test_conv.py::test_op_adaptiveavgpool2d[needle.backend_ndarray.ndarray_backend_cpu-X_shape2-output_size2] ]9;4;1;6\PASSED
# tests/hw4/test_conv.py::test_op_adaptiveavgpool2d[needle.backend_ndarray.ndarray_backend_cpu-X_shape3-output_size3] ]9;4;1;9\PASSED
# ...

# %% [markdown]
# test nn.AdaptiveAvgPool2d in needle

# %%
# !python3 -m pytest -l -v -k "nn_adaptiveaveragepool2d_forward"
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-9.0.1, pluggy-1.6.0 -- /home/rthu/10714/project/.venv/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/rthu/10714/project
# configfile: pyproject.toml
# plugins: jaxtyping-0.3.3
# collecting ... Using needle backend
# collected 2047 items / 2015 deselected / 32 selected
#
# tests/hw4/test_conv.py::test_nn_adaptiveaveragepool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape0-output_size0] ]9;4;1;0\PASSED
# tests/hw4/test_conv.py::test_nn_adaptiveaveragepool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape1-output_size1] ]9;4;1;3\PASSED
# tests/hw4/test_conv.py::test_nn_adaptiveaveragepool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape2-output_size2] ]9;4;1;6\PASSED
# tests/hw4/test_conv.py::test_nn_adaptiveaveragepool2d_forward[needle.backend_ndarray.ndarray_backend_cpu-X_shape3-output_size3] ]9;4;1;9\PASSED
# ...
